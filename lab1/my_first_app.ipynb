# %% [markdown]
# # My First App
#
# Це мій перший застосунок у Python. Тут я вивчаю базовий синтаксис, змінні та вивід даних.

# %%
from datetime import datetime
name = "Volodymyr"
location = "Los Angeles"

print(f"{name} start programming at {datetime.now()}. {location} is the best city!")
# Out:
# Volodymyr start programming at 2026-09-24 09:36:25.402614. Los Angeles is the best city!

# %% [markdown]
# ## Альтернативна програма
#
# Ось інший приклад: простий калькулятор, який підраховує суму двох чисел і виводить результат.

# %%
a = 12
b = 7
sum_result = a + b

print(f"Сума чисел {a} і {b} дорівнює {sum_result}")
# Out:
# Сума чисел 12 і 7 дорівнює 19
